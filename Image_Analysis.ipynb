# %%
# !pip install -Uq google-generativeai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.3 MB/s eta 0:00:00

# %%
import google.generativeai as genai

# %%
from google.colab import userdata
genai.configure(api_key= userdata.get('GEMINI_API_KEY'))

# %%
import os
os.getenv('GEMINI_API_KEY')

# %%
model = genai.GenerativeModel("gemini-2.0-flash-exp")

# %%
import PIL.Image as img
image = img.open('/content/Image_cat.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1350x1096>

# %%
prompt = "what's in the image?"

# %%
response = model.generate_content([prompt, image])

# %%
from IPython.display import display, Markdown
Markdown(response.text)
# Out:
# The image is a close-up photograph of a cat's face, featuring its beautiful light blue eyes, a pink nose, and patterned fur. The cat appears to be a lynx point Siamese or a similar breed with short hair. The background is a plain white color, which makes the cat the central focus of the image.
